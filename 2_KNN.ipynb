# %% [raw]
# Step 1 : Importing the libraries
# Step 2 : Reading the dataset
# Step 3 : Seperating the features and target
# Step 4 : Splitting the dataset into training set and test
# Step 5 : Creating the Model
# Step 6 : Training Model
# Step 7 : Testing the Model
# Step 8 : Check for accuracy
# Step 9 : Confusion Matrix

# %% [markdown]
# # Step 1 : Importing the libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Step 2 : Reading the dataset

# %%
dataset = pd.read_csv("cancer_dataset.csv") # first we need upload the dataset
dataset.head() # will shoe first 5 rows
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Step 3 : Seperating the features and target

# %%
x = dataset.iloc[:,2:32]
y = dataset.iloc[:,1]
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
y.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %% [markdown]
# # Step 4 : Splitting the dataset into training set and test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=42)

# %% [markdown]
# # Step 5 : Creating the Model

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %% [markdown]
# # Step 6 : Training Model

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(x_test) # predicting for all x_test
y_pred
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M'], dtype=object)

# %% [markdown]
# # Step 7 : Testing the Model

# %%
x_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 204        12.47         18.60           81.09      481.9          0.09965
# 70         18.94         21.31          123.60     1130.0          0.09009
# 131        15.46         19.48          101.70      748.9          0.10920
# 431        12.40         17.68           81.47      467.8          0.10540
# 540        11.54         14.44           74.65      402.9          0.09984
# ..           ...           ...             ...        ...              ...
# 486        14.64         16.85           94.21      666.0          0.08641
# 75         16.07         19.65          104.10      817.7          0.09168
# 249        11.52         14.93           73.87      406.3          0.10130
# 238        14.22         27.85           92.55      623.9          0.08223
# 265        20.73         31.12          135.70     1419.0          0.09469
#
# ...

# %%
my_string = get_some_string(x_test)  # Replace with how you obtain the string

if my_string is not None:
    # Now you can safely split my_string
    parts = my_string.split()
else:
    # Handle the case when my_string is None, e.g., provide a default value or raise an error
    print("my_string is None, cannot split it.")


y_pred = model.predict(x_test) # predicting for all x_test
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 my_string = get_some_string(x_test)  # Replace with how you obtain the string
#       3 if my_string is not None:
#       4     # Now you can safely split my_string
#       5     parts = my_string.split()
#
# NameError: name 'get_some_string' is not defined

# %%
pip install --upgrade scikit-learn

# %%
y_test
# Out:
# 204    B
# 70     M
# 131    M
# 431    B
# 540    B
#       ..
# 486    B
# 75     M
# 249    B
# 238    B
# 265    M
# Name: diagnosis, Length: 114, dtype: object

# %%
y_pred
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M'], dtype=object)

# %%
list(zip(y_test,y_pred))
# Out:
# [('B', 'B'),
#  ('M', 'M'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('M', 'M'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('M', 'B'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('M', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('M', 'M'),
#  ('M', 'M'),
#  ('B', 'B'),
#  ('B', 'B'),
#  ('B', 'B'),
# ...

# %% [markdown]
# # Step 8 : Check for accuracy

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test,y_pred)
print(acc*100)
# Out:
# 95.6140350877193

# %% [markdown]
# # Step 9 : Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[71  0]
#  [ 5 38]]
